# %% [markdown]
# # 1.
# Add the current date to the text file today.txt as a string.

# %%
import datetime
# Code to Add current date to the today.txt file
file = open('today.txt','w')
file.write(datetime.datetime.now().strftime("%d-%m-%Y"))
file.close()
# Code to Read current date from today.txt file
file = open('today.txt','r')
print(file.read())
file.close()
# Out:
# 04-10-2023

# %% [markdown]
# # 2.
# Read the text file today.txt into the string today_string

# %%
file = open('today.txt','r')
today_string = file.read()
print(today_string)
# Out:
# 04-10-2023

# %% [markdown]
# # 3.
# Parse the date from today_string.

# %%
from datetime import datetime
format = '%d-%m-%Y'
datetime.strptime(today_string,format)
# Out:
# datetime.datetime(2023, 10, 4, 0, 0)

# %% [markdown]
# # 4.
# List the files in your current directory

# %%
import os
os.listdir('.')
# Out:
# ['.android',
#  '.bash_history',
#  '.cache',
#  '.conda',
#  '.cufflinks',
#  '.dotnet',
#  '.eclipse',
#  '.gitconfig',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.labelImgSettings.pkl',
#  '.matplotlib',
#  '.ms-ad',
#  '.p2',
#  '.packettracer',
#  '.popsql.json',
#  '.spss',
#  '.thumbnails',
#  '.VirtualBox',
#  '.vscode',
#  '3D Objects',
#  'adaboost_demo.ipynb',
#  'addd.csv',
#  'ADVANCED PYTHON ASSIGNMENT 1.ipynb',
#  'all about graph.ipynb',
#  'anaconda3',
#  'anger.txt',
#  'apidatasetextraction.ipynb',
#  'AppData',
#  'Application Data',
#  'application_log.txt',
#  'arc.json',
#  'ashoka_pdf.pdf',
#  'Assignment 1.ipynb',
#  'Assignment_10.ipynb',
#  'Assignment_11.ipynb',
#  'Assignment_12.ipynb',
#  'Assignment_13.ipynb',
#  'Assignment_14.ipynb',
#  'Assignment_15.ipynb',
#  'Assignment_16.ipynb',
#  'Assignment_17.ipynb',
#  'Assignment_18.ipynb',
#  'Assignment_19.ipynb',
#  'Assignment_2.ipynb',
#  'Assignment_20.ipynb',
#  'Assignment_21.ipynb',
#  'Assignment_3.ipynb',
#  'Assignment_4.ipynb',
#  'Assignment_5.ipynb',
#  'Assignment_6.ipynb',
#  'Assignment_7.ipynb',
#  'Assignment_8.ipynb',
#  'Assignment_9.ipynb',
#  'aug_train.csv',
#  'books.csv',
#  'books.db',
#  'cca 3 feb.ipynb',
#  'Cisco Packet Tracer 7.0',
#  'college.csv',
#  'concrete_data.csv',
#  'Contacts',
#  'Cookies',
#  'CSV files.ipynb',
#  'data_science_job.csv',
#  'datetime 3 feb.ipynb',
#  'day 1 revision basic python.ipynb',
#  'day68-stacking',
#  'dddd.csv',
#  'Desktop',
#  'Documents',
#  'DOraemon.ipynb',
#  'Downloads',
#  'exceptionn 26 aug.ipynb',
#  'exercise 1.ipynb',
#  'EXPLORATORY DATA ANALYSIS.ipynb',
#  'extend',
#  'extend.txt',
#  'fault-repo',
#  'Favorites',
#  'fifa',
#  'fifa_group_scrapping.ipynb',
#  'gold_price_data.csv',
#  'http video download.ipynb',
#  'IBA_IOAPDATA',
#  'IdeaProjects',
#  'IntelGraphicsProfiles',
#  'IPL Matches 2008-2020.csv',
#  'jai-shree-ram-hd-hanuman-ebq48hig2eimhppf.jpg',
#  'Links',
#  'Local Settings',
#  'messages.csv',
#  'Microsoft',
#  'MicrosoftEdgeBackups',
#  'movie_titles_metadata.tsv',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'New folder',
#  'new_filename.png',
#  'njnnj',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'numpy.ipynb',
#  'OneDrive',
#  'orders.csv',
#  'output.csv',
#  'output.html',
#  'output.pdf',
#  'PandasProfiling.ipynb',
#  'pepp.pdf',
#  'pic2.jpg',
#  'PicsArt_02-16-08.18.09.jpg',
#  'Pictures',
#  'Postman',
#  'practice for loop-Copy1.ipynb',
#  'practice for loop.ipynb',
#  'PrintHood',
#  'PycharmProjects',
#  'rak',
#  'rakesh.json',
#  'rakesh.txt',
#  'rakeshbind.txt',
#  'readme.md',
#  'Recent',
#  'regression _ linear , ridge , lasso and elastic net.ipynb',
#  'requirements.txt',
#  'REVIEW SCRAPPER --- PYTHON PROJECT.ipynb',
#  'REVISION PYTHON .ipynb',
#  'Roaming',
#  'Saved Games',
#  'seaborn-data',
#  'Searches',
#  'SendTo',
#  'source',
#  'sql.csv',
#  'Start Menu',
#  'Statistics-Left Skewed And Right Skewed Distribution And Relation With Mean Median And Mode.mp4',
#  'svm .ipynb',
#  'Templates',
#  'test.csv',
#  'test.txt',
#  'titanic.csv',
#  'today.txt',
#  'train.csv',
#  'Untitled.ipynb',
#  'untitled.txt',
#  'Untitled1.ipynb',
#  'Untitled10.ipynb',
#  'Untitled11.ipynb',
#  'Untitled12.ipynb',
#  'Untitled13.ipynb',
#  'Untitled14.ipynb',
#  'Untitled15.ipynb',
#  'Untitled16.ipynb',
#  'Untitled17.ipynb',
#  'Untitled18.ipynb',
#  'Untitled19.ipynb',
#  'Untitled2.ipynb',
#  'Untitled20.ipynb',
#  'Untitled21.ipynb',
#  'Untitled22.ipynb',
#  'Untitled23.ipynb',
#  'Untitled24.ipynb',
#  'Untitled25.ipynb',
#  'Untitled26.ipynb',
#  'Untitled27.ipynb',
#  'Untitled28.ipynb',
#  'Untitled29.ipynb',
#  'Untitled3.ipynb',
#  'Untitled30.ipynb',
#  'Untitled31.ipynb',
#  'Untitled32.ipynb',
#  'Untitled33.ipynb',
#  'Untitled34.ipynb',
#  'Untitled35.ipynb',
#  'Untitled36.ipynb',
#  'Untitled37.ipynb',
#  'Untitled38.ipynb',
#  'Untitled39.ipynb',
#  'Untitled4.ipynb',
#  'Untitled40.ipynb',
#  'Untitled41.ipynb',
#  'Untitled42.ipynb',
#  'Untitled43.ipynb',
#  'Untitled44.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb',
#  'value.csv',
#  'Videos',
#  'VirtualBox VMs',
#  'webscrapAMBITIONBOX.ipynb',
#  'working-with-csv.ipynb',
#  'Youtube videos download.ipynb',
#  'zomato.csv',
#  'zoo.ipynb',
#  'zoo.py',
#  '__pycache__']

# %% [markdown]
# # 5.
# Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
import os 
os.listdir()
# Out:
# ['.android',
#  '.bash_history',
#  '.cache',
#  '.conda',
#  '.cufflinks',
#  '.dotnet',
#  '.eclipse',
#  '.gitconfig',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.labelImgSettings.pkl',
#  '.matplotlib',
#  '.ms-ad',
#  '.p2',
#  '.packettracer',
#  '.popsql.json',
#  '.spss',
#  '.thumbnails',
#  '.VirtualBox',
#  '.vscode',
#  '3D Objects',
#  'adaboost_demo.ipynb',
#  'addd.csv',
#  'ADVANCED PYTHON ASSIGNMENT 1.ipynb',
#  'all about graph.ipynb',
#  'anaconda3',
#  'anger.txt',
#  'apidatasetextraction.ipynb',
#  'AppData',
#  'Application Data',
#  'application_log.txt',
#  'arc.json',
#  'ashoka_pdf.pdf',
#  'Assignment 1.ipynb',
#  'Assignment_10.ipynb',
#  'Assignment_11.ipynb',
#  'Assignment_12.ipynb',
#  'Assignment_13.ipynb',
#  'Assignment_14.ipynb',
#  'Assignment_15.ipynb',
#  'Assignment_16.ipynb',
#  'Assignment_17.ipynb',
#  'Assignment_18.ipynb',
#  'Assignment_19.ipynb',
#  'Assignment_2.ipynb',
#  'Assignment_20.ipynb',
#  'Assignment_21.ipynb',
#  'Assignment_3.ipynb',
#  'Assignment_4.ipynb',
#  'Assignment_5.ipynb',
#  'Assignment_6.ipynb',
#  'Assignment_7.ipynb',
#  'Assignment_8.ipynb',
#  'Assignment_9.ipynb',
#  'aug_train.csv',
#  'books.csv',
#  'books.db',
#  'cca 3 feb.ipynb',
#  'Cisco Packet Tracer 7.0',
#  'college.csv',
#  'concrete_data.csv',
#  'Contacts',
#  'Cookies',
#  'CSV files.ipynb',
#  'data_science_job.csv',
#  'datetime 3 feb.ipynb',
#  'day 1 revision basic python.ipynb',
#  'day68-stacking',
#  'dddd.csv',
#  'Desktop',
#  'Documents',
#  'DOraemon.ipynb',
#  'Downloads',
#  'exceptionn 26 aug.ipynb',
#  'exercise 1.ipynb',
#  'EXPLORATORY DATA ANALYSIS.ipynb',
#  'extend',
#  'extend.txt',
#  'fault-repo',
#  'Favorites',
#  'fifa',
#  'fifa_group_scrapping.ipynb',
#  'gold_price_data.csv',
#  'http video download.ipynb',
#  'IBA_IOAPDATA',
#  'IdeaProjects',
#  'IntelGraphicsProfiles',
#  'IPL Matches 2008-2020.csv',
#  'jai-shree-ram-hd-hanuman-ebq48hig2eimhppf.jpg',
#  'Links',
#  'Local Settings',
#  'messages.csv',
#  'Microsoft',
#  'MicrosoftEdgeBackups',
#  'movie_titles_metadata.tsv',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'New folder',
#  'new_filename.png',
#  'njnnj',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'numpy.ipynb',
#  'OneDrive',
#  'orders.csv',
#  'output.csv',
#  'output.html',
#  'output.pdf',
#  'PandasProfiling.ipynb',
#  'pepp.pdf',
#  'pic2.jpg',
#  'PicsArt_02-16-08.18.09.jpg',
#  'Pictures',
#  'Postman',
#  'practice for loop-Copy1.ipynb',
#  'practice for loop.ipynb',
#  'PrintHood',
#  'PycharmProjects',
#  'rak',
#  'rakesh.json',
#  'rakesh.txt',
#  'rakeshbind.txt',
#  'readme.md',
#  'Recent',
#  'regression _ linear , ridge , lasso and elastic net.ipynb',
#  'requirements.txt',
#  'REVIEW SCRAPPER --- PYTHON PROJECT.ipynb',
#  'REVISION PYTHON .ipynb',
#  'Roaming',
#  'Saved Games',
#  'seaborn-data',
#  'Searches',
#  'SendTo',
#  'source',
#  'sql.csv',
#  'Start Menu',
#  'Statistics-Left Skewed And Right Skewed Distribution And Relation With Mean Median And Mode.mp4',
#  'svm .ipynb',
#  'Templates',
#  'test.csv',
#  'test.txt',
#  'titanic.csv',
#  'today.txt',
#  'train.csv',
#  'Untitled.ipynb',
#  'untitled.txt',
#  'Untitled1.ipynb',
#  'Untitled10.ipynb',
#  'Untitled11.ipynb',
#  'Untitled12.ipynb',
#  'Untitled13.ipynb',
#  'Untitled14.ipynb',
#  'Untitled15.ipynb',
#  'Untitled16.ipynb',
#  'Untitled17.ipynb',
#  'Untitled18.ipynb',
#  'Untitled19.ipynb',
#  'Untitled2.ipynb',
#  'Untitled20.ipynb',
#  'Untitled21.ipynb',
#  'Untitled22.ipynb',
#  'Untitled23.ipynb',
#  'Untitled24.ipynb',
#  'Untitled25.ipynb',
#  'Untitled26.ipynb',
#  'Untitled27.ipynb',
#  'Untitled28.ipynb',
#  'Untitled29.ipynb',
#  'Untitled3.ipynb',
#  'Untitled30.ipynb',
#  'Untitled31.ipynb',
#  'Untitled32.ipynb',
#  'Untitled33.ipynb',
#  'Untitled34.ipynb',
#  'Untitled35.ipynb',
#  'Untitled36.ipynb',
#  'Untitled37.ipynb',
#  'Untitled38.ipynb',
#  'Untitled39.ipynb',
#  'Untitled4.ipynb',
#  'Untitled40.ipynb',
#  'Untitled41.ipynb',
#  'Untitled42.ipynb',
#  'Untitled43.ipynb',
#  'Untitled44.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb',
#  'value.csv',
#  'Videos',
#  'VirtualBox VMs',
#  'webscrapAMBITIONBOX.ipynb',
#  'working-with-csv.ipynb',
#  'Youtube videos download.ipynb',
#  'zomato.csv',
#  'zoo.ipynb',
#  'zoo.py',
#  '__pycache__']

# %% [markdown]
# # 6.
# Use multiprocessing to create three separate processes. Make each one wait a random number of
# seconds between one and five, print the current time, and then exit.

# %%
import multiprocessing

def printsec(seconds):
    from datetime import datetime
    from time import sleep
    sleep(seconds)
    print('wait', seconds, 'seconds, time is', datetime.utcnow())
    
if __name__ == '__main__':
    import random    
    for n in range(3):
        seconds = random.random()
        proc = multiprocessing.Process(target=printsec, args=(seconds,))
        proc.start()

# %% [markdown]
# # 7.
# Create a date object of your day of birth.

# %%
from datetime import datetime
my_dob = datetime.strptime('24/08/2000','%d/%m/%Y')
print(my_dob, type(my_dob))
# Out:
# 2000-08-24 00:00:00 <class 'datetime.datetime'>

# %% [markdown]
# # 8.
# What day of the week was your day of birth?

# %%
from datetime import datetime
my_dob = datetime(2000,8,24)
my_dob.strftime("%A")
# Out:
# 'Thursday'

# %% [markdown]
# # 9.
# When will you be (or when were you) 10,000 days old?

# %%
from datetime import timedelta
day10000 = my_dob + timedelta(days=10000)
day10000
# Out:
# datetime.datetime(2028, 1, 10, 0, 0)
